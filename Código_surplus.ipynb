# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dados_consumo=pd.read_csv("dados_consumo.csv", sep=";", header=None)

# %%
dados_consumo
# Out:
#                       0         1      2
# 0      01/01/2018 00:15  janeiro     160
# 1      01/01/2018 00:30  janeiro     160
# 2      01/01/2018 00:45   janeiro  157,5
# 3      01/01/2018 01:00   janeiro    160
# 4      01/01/2018 01:15   janeiro  157,5
# ...                 ...       ...    ...
# 34941    12/31/18 22:45  dezembro  172,5
# 34942    12/31/18 23:00  dezembro    170
# 34943    12/31/18 23:15  dezembro    170
# 34944    12/31/18 23:30  dezembro  167,5
# 34945    12/31/18 23:45  dezembro    170
#
# [34946 rows x 3 columns]

# %%
dados_consumo.rename({0:'Date',
           1:'Month',
           2:'Cons'},axis=1,inplace=True)

# %%
dados_consumo
# Out:
#                    Date     Month   Cons
# 0      01/01/2018 00:15  janeiro     160
# 1      01/01/2018 00:30  janeiro     160
# 2      01/01/2018 00:45   janeiro  157,5
# 3      01/01/2018 01:00   janeiro    160
# 4      01/01/2018 01:15   janeiro  157,5
# ...                 ...       ...    ...
# 34941    12/31/18 22:45  dezembro  172,5
# 34942    12/31/18 23:00  dezembro    170
# 34943    12/31/18 23:15  dezembro    170
# 34944    12/31/18 23:30  dezembro  167,5
# 34945    12/31/18 23:45  dezembro    170
#
# [34946 rows x 3 columns]

# %%
dados_consumo.describe()
# Out:
#                  Date    Month   Cons
# count           34946    34946  34946
# unique          34942       14    260
# top     10/28/18 1:00  outubro  197,5
# freq                2     2980   1156

# %%
dados_consumo.describe()
# Out:
#                  Date    Month   Cons
# count           34946    34946  34946
# unique          34942       14    260
# top     10/28/18 1:00  outubro  197,5
# freq                2     2980   1156

# %%
dados_consumo
# Out:
#                    Date     Month   Cons
# 0      01/01/2018 00:15  janeiro     160
# 1      01/01/2018 00:30  janeiro     160
# 2      01/01/2018 00:45   janeiro  157,5
# 3      01/01/2018 01:00   janeiro    160
# 4      01/01/2018 01:15   janeiro  157,5
# ...                 ...       ...    ...
# 34941    12/31/18 22:45  dezembro  172,5
# 34942    12/31/18 23:00  dezembro    170
# 34943    12/31/18 23:15  dezembro    170
# 34944    12/31/18 23:30  dezembro  167,5
# 34945    12/31/18 23:45  dezembro    170
#
# [34946 rows x 3 columns]

# %%
dados_consumo.index=pd.to_datetime(dados_consumo['Date'])

# %%
dados_consumo
# Out:
#                                  Date     Month   Cons
# Date
# 2018-01-01 00:15:00  01/01/2018 00:15  janeiro     160
# 2018-01-01 00:30:00  01/01/2018 00:30  janeiro     160
# 2018-01-01 00:45:00  01/01/2018 00:45   janeiro  157,5
# 2018-01-01 01:00:00  01/01/2018 01:00   janeiro    160
# 2018-01-01 01:15:00  01/01/2018 01:15   janeiro  157,5
# ...                               ...       ...    ...
# 2018-12-31 22:45:00    12/31/18 22:45  dezembro  172,5
# 2018-12-31 23:00:00    12/31/18 23:00  dezembro    170
# 2018-12-31 23:15:00    12/31/18 23:15  dezembro    170
# 2018-12-31 23:30:00    12/31/18 23:30  dezembro  167,5
# 2018-12-31 23:45:00    12/31/18 23:45  dezembro    170
#
# [34946 rows x 3 columns]

# %%
dados_consumo.drop('Date',axis=1,inplace=True)

# %%
dados_consumo
# Out:
#                         Month   Cons
# Date
# 2018-01-01 00:15:00  janeiro     160
# 2018-01-01 00:30:00  janeiro     160
# 2018-01-01 00:45:00   janeiro  157,5
# 2018-01-01 01:00:00   janeiro    160
# 2018-01-01 01:15:00   janeiro  157,5
# ...                       ...    ...
# 2018-12-31 22:45:00  dezembro  172,5
# 2018-12-31 23:00:00  dezembro    170
# 2018-12-31 23:15:00  dezembro    170
# 2018-12-31 23:30:00  dezembro  167,5
# 2018-12-31 23:45:00  dezembro    170
#
# [34946 rows x 2 columns]

# %%
dados_consumo['Cons']['2018-01':'2018-02']
# Out:
# C:\Users\irvyl\AppData\Local\Temp\ipykernel_44272\1045544828.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   dados_consumo['Cons']['2018-01':'2018-02']
# Date
# 2018-01-01 00:15:00         160
# 2018-01-01 00:30:00         160
# 2018-01-01 00:45:00       157,5
# 2018-01-01 01:00:00         160
# 2018-01-01 01:15:00       157,5
#                          ...
# 2018-02-27 23:30:00         250
# 2018-02-27 23:45:00       242,5
# 2018-02-28 00:00:00       242,5
# 2018-02-28 00:15:00    834582,5
# 2018-02-28 00:30:00    834,5825
# Name: Cons, Length: 5570, dtype: object

# %%
dados_consumo.loc[dados_consumo.index.hour==0]
# Out:
#                         Month   Cons
# Date
# 2018-01-01 00:15:00  janeiro     160
# 2018-01-01 00:30:00  janeiro     160
# 2018-01-01 00:45:00   janeiro  157,5
# 2018-01-02 00:00:00   janeiro  162,5
# 2018-01-02 00:15:00   janeiro  167,5
# ...                       ...    ...
# 2018-12-30 00:45:00  dezembro    175
# 2018-12-31 00:00:00  dezembro    175
# 2018-12-31 00:15:00  dezembro  172,5
# 2018-12-31 00:30:00  dezembro  172,5
# 2018-12-31 00:45:00  dezembro    175
#
# [1458 rows x 2 columns]

# %%
dados_consumo.loc[(dados_consumo.index.hour==0)&(dados_consumo.index.minute==15)]
# Out:
#                         Month   Cons
# Date
# 2018-01-01 00:15:00  janeiro     160
# 2018-01-02 00:15:00   janeiro  167,5
# 2018-01-03 00:15:00   janeiro    190
# 2018-01-04 00:15:00   janeiro  207,5
# 2018-01-05 00:15:00   janeiro  202,5
# ...                       ...    ...
# 2018-12-27 00:15:00  dezembro    185
# 2018-12-28 00:15:00  dezembro    180
# 2018-12-29 00:15:00  dezembro  182,5
# 2018-12-30 00:15:00  dezembro    175
# 2018-12-31 00:15:00  dezembro  172,5
#
# [365 rows x 2 columns]

# %%
dados_consumo.loc[((dados_consumo.index.hour==0)&(dados_consumo.index.minute==15)&((dados_consumo.index.month==1))|(dados_consumo.index.month==33))]
# Out:
#                         Month   Cons
# Date
# 2018-01-01 00:15:00  janeiro     160
# 2018-01-02 00:15:00   janeiro  167,5
# 2018-01-03 00:15:00   janeiro    190
# 2018-01-04 00:15:00   janeiro  207,5
# 2018-01-05 00:15:00   janeiro  202,5
# 2018-01-06 00:15:00   janeiro    205
# 2018-01-07 00:15:00   janeiro    205
# 2018-01-08 00:15:00   janeiro    205
# 2018-01-09 00:15:00   janeiro  222,5
# 2018-01-10 00:15:00   janeiro    220
# 2018-01-11 00:15:00   janeiro  222,5
# 2018-01-12 00:15:00   janeiro    215
# 2018-01-13 00:15:00   janeiro  202,5
# 2018-01-14 00:15:00   janeiro    205
# 2018-01-15 00:15:00   janeiro  207,5
# 2018-01-16 00:15:00   janeiro    225
# 2018-01-17 00:15:00   janeiro  222,5
# 2018-01-18 00:15:00   janeiro  222,5
# 2018-01-19 00:15:00   janeiro  222,5
# 2018-01-20 00:15:00   janeiro    205
# 2018-01-21 00:15:00   janeiro  197,5
# 2018-01-22 00:15:00   janeiro  197,5
# 2018-01-23 00:15:00   janeiro    215
# 2018-01-24 00:15:00   janeiro  217,5
# ...

# %%
print(dados_consumo)
dados_consumo.drop('Month',axis=1,inplace=True)
dados_consumo['Cons']=dados_consumo['Cons'].str.replace(',','.')
dados_consumo['Cons']=dados_consumo['Cons'].astype(float)
dados_consumo=dados_consumo.resample('1h').sum()
# Out:
#                         Month   Cons
# Date
# 2018-01-01 00:15:00  janeiro     160
# 2018-01-01 00:30:00  janeiro     160
# 2018-01-01 00:45:00   janeiro  157,5
# 2018-01-01 01:00:00   janeiro    160
# 2018-01-01 01:15:00   janeiro  157,5
# ...                       ...    ...
# 2018-12-31 22:45:00  dezembro  172,5
# 2018-12-31 23:00:00  dezembro    170
# 2018-12-31 23:15:00  dezembro    170
# 2018-12-31 23:30:00  dezembro  167,5
# 2018-12-31 23:45:00  dezembro    170
#
# [34946 rows x 2 columns]

# %%
dados_consumo
# Out:
#                       Cons
# Date
# 2018-01-01 00:00:00  477.5
# 2018-01-01 01:00:00  645.0
# 2018-01-01 02:00:00  640.0
# 2018-01-01 03:00:00  635.0
# 2018-01-01 04:00:00  635.0
# ...                    ...
# 2018-12-31 19:00:00  835.0
# 2018-12-31 20:00:00  740.0
# 2018-12-31 21:00:00  715.0
# 2018-12-31 22:00:00  695.0
# 2018-12-31 23:00:00  677.5
#
# [8760 rows x 1 columns]

# %%
dados_consumo['Cons']=dados_consumo['Cons'].resample('1h').sum()

# %%
dados_consumo['2018-12-01'].describe()
# Out:
# C:\Users\irvyl\AppData\Local\Temp\ipykernel_44272\3077174407.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   dados_consumo['2018-12-01'].describe()
#              Cons
# count   24.000000
# mean   824.479167
# std     60.392643
# min    735.000000
# 25%    786.875000
# 50%    822.500000
# 75%    850.625000
# max    955.000000

# %%
dados_irradiacao=pd.read_csv("dados_irradiacao.csv", sep=";")

# %%
dados_irradiacao
# Out:
#      hora       mês Irradiacao
# 0       0   janeiro          0
# 1       1   janeiro          0
# 2       2   janeiro          0
# 3       3   janeiro          0
# 4       4   janeiro          0
# ..    ...       ...        ...
# 283    19  Dezembro          0
# 284    20  Dezembro          0
# 285    21  Dezembro          0
# 286    22  Dezembro          0
# 287    23  Dezembro          0
#
# [288 rows x 3 columns]

# %%
dados_irradiacao.describe()
# Out:
#              hora
# count  288.000000
# mean    11.500000
# std      6.934236
# min      0.000000
# 25%      5.750000
# 50%     11.500000
# 75%     17.250000
# max     23.000000

# %%
dados_irradiacao.plot()
# Out:
# <AxesSubplot: >

# %%
dados_irradiacao['Irradiacao']=dados_irradiacao['Irradiacao'].str.replace(',','.').astype(float)

# %%
area=4317
def PV_out(dados_irradiacao):
    dados_irradiacao['PV_Out']=dados_irradiacao['Irradiacao']*0.15*0.95*area
    return dados_irradiacao

# %%
PV_out(dados_irradiacao)
# Out:
#      hora       mês  Irradiacao  PV_Out
# 0       0   janeiro         0.0     0.0
# 1       1   janeiro         0.0     0.0
# 2       2   janeiro         0.0     0.0
# 3       3   janeiro         0.0     0.0
# 4       4   janeiro         0.0     0.0
# ..    ...       ...         ...     ...
# 283    19  Dezembro         0.0     0.0
# 284    20  Dezembro         0.0     0.0
# 285    21  Dezembro         0.0     0.0
# 286    22  Dezembro         0.0     0.0
# 287    23  Dezembro         0.0     0.0
#
# [288 rows x 4 columns]

# %%
dados_consumo
# Out:
#                       Cons
# Date
# 2018-01-01 00:00:00  477.5
# 2018-01-01 01:00:00  645.0
# 2018-01-01 02:00:00  640.0
# 2018-01-01 03:00:00  635.0
# 2018-01-01 04:00:00  635.0
# ...                    ...
# 2018-12-31 19:00:00  835.0
# 2018-12-31 20:00:00  740.0
# 2018-12-31 21:00:00  715.0
# 2018-12-31 22:00:00  695.0
# 2018-12-31 23:00:00  677.5
#
# [8760 rows x 1 columns]

# %%
dados_irradiacao.loc[(dados_irradiacao.hora==0) & (dados_irradiacao.mês=="janeiro")]
months=['janeiro','fevereiro']
for i,row in dados_consumo.iterrows():
    print(i)
    dados_consumo.loc[i,'Irradiacao']=dados_irradiacao.loc[(dados_irradiacao.hora==i.hour) & (dados_irradiacao.mês==dados_irradiacao['mês'].unique()[i.month-1]),'Irradiacao'].values[0]
    print(dados_consumo.loc[i,'Irradiacao'])
# Out:
# 2018-01-01 00:00:00
# 0.0
# 2018-01-01 01:00:00
# 0.0
# 2018-01-01 02:00:00
# 0.0
# 2018-01-01 03:00:00
# 0.0
# 2018-01-01 04:00:00
# 0.0
# 2018-01-01 05:00:00
# 0.0
# 2018-01-01 06:00:00
# 0.0
# 2018-01-01 07:00:00
# 0.125
# 2018-01-01 08:00:00
# 0.335
# 2018-01-01 09:00:00
# 0.409
# 2018-01-01 10:00:00
# 0.442
# 2018-01-01 11:00:00
# 0.449
# 2018-01-01 12:00:00
# 0.429
# 2018-01-01 13:00:00
# 0.407
# 2018-01-01 14:00:00
# 0.373
# 2018-01-01 15:00:00
# 0.242
# 2018-01-01 16:00:00
# 0.007
# 2018-01-01 17:00:00
# 0.0
# 2018-01-01 18:00:00
# 0.0
# 2018-01-01 19:00:00
# 0.0
# 2018-01-01 20:00:00
# 0.0
# 2018-01-01 21:00:00
# 0.0
# 2018-01-01 22:00:00
# 0.0
# 2018-01-01 23:00:00
# 0.0
# 2018-01-02 00:00:00
# 0.0
# 2018-01-02 01:00:00
# 0.0
# 2018-01-02 02:00:00
# 0.0
# 2018-01-02 03:00:00
# 0.0
# 2018-01-02 04:00:00
# 0.0
# 2018-01-02 05:00:00
# 0.0
# 2018-01-02 06:00:00
# 0.0
# 2018-01-02 07:00:00
# 0.125
# 2018-01-02 08:00:00
# 0.335
# 2018-01-02 09:00:00
# 0.409
# 2018-01-02 10:00:00
# ...

# %%
dados_consumo
# Out:
#                       Cons  Irradiacao
# Date
# 2018-01-01 00:00:00  477.5         0.0
# 2018-01-01 01:00:00  645.0         0.0
# 2018-01-01 02:00:00  640.0         0.0
# 2018-01-01 03:00:00  635.0         0.0
# 2018-01-01 04:00:00  635.0         0.0
# ...                    ...         ...
# 2018-12-31 19:00:00  835.0         0.0
# 2018-12-31 20:00:00  740.0         0.0
# 2018-12-31 21:00:00  715.0         0.0
# 2018-12-31 22:00:00  695.0         0.0
# 2018-12-31 23:00:00  677.5         0.0
#
# [8760 rows x 2 columns]

# %%
dados_consumo = PV_out(dados_consumo)

# %%
dados_irradiacao.loc[(dados_irradiacao.hora==0) & (dados_irradiacao.mês=="janeiro"),'Irradiacao'].values[0]
# Out:
# 0.0

# %%
dados_irradiacao
# Out:
#      hora       mês  Irradiacao  PV_Out
# 0       0   janeiro         0.0     0.0
# 1       1   janeiro         0.0     0.0
# 2       2   janeiro         0.0     0.0
# 3       3   janeiro         0.0     0.0
# 4       4   janeiro         0.0     0.0
# ..    ...       ...         ...     ...
# 283    19  Dezembro         0.0     0.0
# 284    20  Dezembro         0.0     0.0
# 285    21  Dezembro         0.0     0.0
# 286    22  Dezembro         0.0     0.0
# 287    23  Dezembro         0.0     0.0
#
# [288 rows x 4 columns]

# %%
dados_irradiacao['mês'].unique()[0]
# Out:
# 'janeiro'

# %%
dados_consumo
# Out:
#                       Cons  Irradiacao  PV_Out
# Date
# 2018-01-01 00:00:00  477.5         0.0     0.0
# 2018-01-01 01:00:00  645.0         0.0     0.0
# 2018-01-01 02:00:00  640.0         0.0     0.0
# 2018-01-01 03:00:00  635.0         0.0     0.0
# 2018-01-01 04:00:00  635.0         0.0     0.0
# ...                    ...         ...     ...
# 2018-12-31 19:00:00  835.0         0.0     0.0
# 2018-12-31 20:00:00  740.0         0.0     0.0
# 2018-12-31 21:00:00  715.0         0.0     0.0
# 2018-12-31 22:00:00  695.0         0.0     0.0
# 2018-12-31 23:00:00  677.5         0.0     0.0
#
# [8760 rows x 3 columns]

# %%
dados_consumo['Surplus']=dados_consumo['PV_Out']-dados_consumo['Cons']

# %%
dados_consumo
# Out:
#                       Cons  Irradiacao  PV_Out  Surplus
# Date
# 2018-01-01 00:00:00  477.5         0.0     0.0   -477.5
# 2018-01-01 01:00:00  645.0         0.0     0.0   -645.0
# 2018-01-01 02:00:00  640.0         0.0     0.0   -640.0
# 2018-01-01 03:00:00  635.0         0.0     0.0   -635.0
# 2018-01-01 04:00:00  635.0         0.0     0.0   -635.0
# ...                    ...         ...     ...      ...
# 2018-12-31 19:00:00  835.0         0.0     0.0   -835.0
# 2018-12-31 20:00:00  740.0         0.0     0.0   -740.0
# 2018-12-31 21:00:00  715.0         0.0     0.0   -715.0
# 2018-12-31 22:00:00  695.0         0.0     0.0   -695.0
# 2018-12-31 23:00:00  677.5         0.0     0.0   -677.5
#
# [8760 rows x 4 columns]

# %%
dados_consumo.to_csv('dados.csv')

# %%
dados_consumo[['PV_Out','Cons','Surplus']].loc[dados_consumo.index.month==1].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
dados_consumo[['PV_Out','Cons','Surplus']].loc[dados_consumo.index.month==3].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
dados_consumo[['PV_Out','Cons','Surplus']].loc[(dados_consumo.index.month==1)&(dados_consumo.index.day==1)].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
dados_consumo[['PV_Out','Cons','Surplus']].loc[(dados_consumo.index.month==2)&(dados_consumo.index.day==1)].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
dados_consumo[['PV_Out','Cons','Surplus']].loc[(dados_consumo.index.month==3)&(dados_consumo.index.day==1)].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
dados_consumo[['PV_Out','Cons','Surplus']].loc[(dados_consumo.index.month==4)&(dados_consumo.index.day==1)].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
for i in range(1,13):
    dados_consumo[['PV_Out','Cons','Surplus']].loc[(dados_consumo.index.month==i)&(dados_consumo.index.day==1)].plot()

# %%
dados_consumo['Cons']=dados_consumo['Cons']/1.5
dados_consumo['Surplus']=dados_consumo['PV_Out']-dados_consumo['Cons']

# %%
for i in range(1,13):
    dados_consumo[['PV_Out','Cons','Surplus']].loc[(dados_consumo.index.month==i)&(dados_consumo.index.day==1)].plot()

# %%
for i in range(1,13):
    print(i, ":", dados_consumo['Surplus'].loc[(dados_consumo.index.month==i)].mean())
# Out:
# 1 : 55.67952386424731
# 2 : 49.75579413876488
# 3 : 91.08027333333334
# 4 : 111.42917108796294
# 5 : 129.18802309587812
# 6 : 158.3401460648148
# 7 : 176.319128468862
# 8 : 167.29295937499995
# 9 : 118.13640737268517
# 10 : 75.69738382056451
# 11 : 60.340050648148136
# 12 : 53.36262891017026
